# %%
# This file contains exploration of various statistical distribution and estimating population parameters using sample data

# %%
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np
import random
mean1 = -10
sigma1 = 20

# %%
p = np.random.normal(mean2, sigma2, 1000000)
chisquare = [x * x for x in p]
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(1, 2, 1)
ax.set_title('Random Normal Variable (X)')
sns.distplot(p, ax = ax, hist = True, kde =True)
ax = fig.add_subplot(1, 2, 2)
ax.set_title('Chi Square Random Variable (X ** 2)')
sns.distplot(chisquare, ax = ax, hist = True, kde = True)
